# %% [markdown]
# # Matplotlib

# %%
# 다양한 형태의 그래프를 통해서 대이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000002EC95C01E50>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')
# C:\Users\jukim\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jukim\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jukim\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jukim\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jukim\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jukim\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'cmsy10',
#  'DejaVu Sans Display',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'cmr10',
#  'cmtt10',
#  'DejaVu Sans Mono',
#  'DejaVu Serif Display',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXSizeThreeSym',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'cmb10',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'cmex10',
#  'cmmi10',
#  'cmss10',
#  'STIXSizeThreeSym',
#  'HYGraphic-Medium',
#  'HancomEQN',
#  'Candara',
#  'Gill Sans MT',
#  'Calibri',
#  'Algerian',
#  'Agency FB',
#  'HCR Batang',
#  'Century',
#  'Trebuchet MS',
#  'Microsoft Yi Baiti',
#  'Bookman Old Style',
#  'Perpetua',
#  'Californian FB',
#  'Franklin Gothic Book',
#  'Vladimir Script',
#  'Segoe UI Symbol',
#  'Arial',
#  'Han Santteut Dotum',
#  'Georgia',
#  'Yu Gothic',
#  'Maiandra GD',
#  'Candara',
#  'Rockwell',
#  'NewJumja',
#  'Lucida Fax',
#  'Trebuchet MS',
#  'Tahoma',
#  'Yu Gothic',
#  'Segoe UI',
#  'Han Santteut Dotum',
#  'Perpetua',
#  'Calibri',
#  'Calibri',
#  'Gill Sans Ultra Bold',
#  'Microsoft PhagsPa',
#  'Ebrima',
#  'Magic R',
#  'Centaur',
#  'Berlin Sans FB',
#  'Segoe UI Emoji',
#  'Kunstler Script',
#  'Constantia',
#  'Modern No. 20',
#  'Arial',
#  'Bodoni MT',
#  'Nirmala UI',
#  'Arial',
#  'Bell MT',
#  'Rockwell Condensed',
#  'HCR Batang',
#  'Wingdings',
#  'Hancom Gothic',
#  'STXinwei',
#  'Gloucester MT Extra Condensed',
#  'Microsoft New Tai Lue',
#  'HYGothic-Extra',
#  'HCR Dotum',
#  'NanumGothic',
#  'Bookman Old Style',
#  'Microsoft JhengHei',
#  'Franklin Gothic Heavy',
#  'HCR Dotum',
#  'Segoe Print',
#  'SimSun',
#  'NanumGothic',
#  'Corbel',
#  'Comic Sans MS',
#  'MS Outlook',
#  'Times New Roman',
#  'Arial',
#  'Courier New',
#  'High Tower Text',
#  'Tw Cen MT',
#  'Microsoft New Tai Lue',
#  'High Tower Text',
#  'Wingdings 2',
#  'Jokerman',
#  'Segoe UI',
#  'French Script MT',
#  'Trebuchet MS',
#  'Parchment',
#  'Century Schoolbook',
#  'Hancom Gothic',
#  'Segoe UI Historic',
#  'NewJumja',
#  'HYPMokGak-Bold',
#  'Script MT Bold',
#  'Georgia',
#  'Bauhaus 93',
#  'Goudy Stout',
#  'Lucida Fax',
#  'Franklin Gothic Book',
#  'HCR Batang Ext',
#  'Segoe UI',
#  'Century Gothic',
#  'Lucida Sans',
#  'Bodoni MT',
#  'Candara',
#  'MS Gothic',
#  'Eras Demi ITC',
#  'Corbel',
#  'Book Antiqua',
#  'Ami R',
#  'Wingdings 3',
#  'HCR Batang',
#  'Gill Sans MT Condensed',
#  'MS Gothic',
#  'Myanmar Text',
#  'Ebrima',
#  'Myanmar Text',
#  'Consolas',
#  'Noto Sans Korean',
#  'Harrington',
#  'Eras Bold ITC',
#  'Segoe UI',
#  'Corbel',
#  'Bodoni MT',
#  'Arial Rounded MT Bold',
#  'Cambria',
#  'Copperplate Gothic Bold',
#  'Gadugi',
#  'Lucida Fax',
#  'Tahoma',
#  'Gill Sans Ultra Bold Condensed',
#  'Goudy Old Style',
#  'Centaur',
#  'Palace Script MT',
#  'Segoe UI',
#  'Engravers MT',
#  'UttumDotumMR',
#  'Microsoft YaHei',
#  'Candara',
#  'Batang',
#  'Franklin Gothic Book',
#  'Yu Gothic',
#  'Showcard Gothic',
#  'Californian FB',
#  'Verdana',
#  'Bell MT',
#  'Symbol',
#  'Arial',
#  'Lucida Fax',
#  'STXingkai',
#  'Playbill',
#  'Tw Cen MT Condensed',
#  'Book Antiqua',
#  'STSong',
#  'STHupo',
#  'HoloLens MDL2 Assets',
#  'STSong',
#  'Edwardian Script ITC',
#  'Calisto MT',
#  'Candara',
#  'Segoe UI',
#  'Dubai',
#  'Bodoni MT',
#  'Microsoft JhengHei',
#  'Corbel',
#  'Segoe UI',
#  'Copperplate Gothic Bold',
#  'Comic Sans MS',
#  'Elephant',
#  'Leelawadee UI',
#  'Nina',
#  'Palatino Linotype',
#  'Rockwell',
#  'Franklin Gothic Medium',
#  'Franklin Gothic Demi',
#  'Tw Cen MT',
#  'Californian FB',
#  'Lucida Bright',
#  'Times New Roman',
#  'Blackadder ITC',
#  'Magneto',
#  'Verdana',
#  'MoeumT R',
#  'MV Boli',
#  'STXinwei',
#  'Segoe UI Emoji',
#  'Pyunji R',
#  'Malgun Gothic',
#  'HancomEQN',
#  'Malgun Gothic',
#  'Lucida Sans',
#  'Segoe UI',
#  'Maiandra GD',
#  'Elephant',
#  'Microsoft Tai Le',
#  'Bahnschrift',
#  'HYSinMyeongJo-Medium',
#  'Lucida Bright',
#  'Microsoft New Tai Lue',
#  'Constantia',
#  'Gill Sans MT Ext Condensed Bold',
#  'Consolas',
#  'Calisto MT',
#  'Eras Medium ITC',
#  'Lucida Calligraphy',
#  'Poor Richard',
#  'Gadugi',
#  'UttumDotumMR',
#  'Comic Sans MS',
#  'New Gulim',
#  'MingLiU-ExtB',
#  'Noto Sans Korean',
#  'Candara',
#  'Gill Sans MT',
#  'Candara',
#  'Rockwell',
#  'Book Antiqua',
#  'HYPost-Light',
#  'Sitka',
#  'Garamond',
#  'Eras Light ITC',
#  'Calisto MT',
#  'Microsoft YaHei',
#  'Perpetua',
#  'Book Antiqua',
#  'Dubai',
#  'Footlight MT Light',
#  'Berlin Sans FB Demi',
#  'Arial',
#  'Gill Sans MT',
#  'Lucida Sans Typewriter',
#  'Vivaldi',
#  'Tahoma',
#  'Gill Sans MT Condensed',
#  'NanumGothic',
#  'Yet R',
#  'Bookshelf Symbol 7',
#  'Tahoma',
#  'Calibri',
#  'HYMyeongJo-Extra',
#  'KBFG Text',
#  'Lucida Bright',
#  'Goudy Old Style',
#  'Wingdings 3',
#  'Cambria',
#  'Lucida Sans Unicode',
#  'OCR A Extended',
#  'Leelawadee UI',
#  'Brush Script MT',
#  'Jokerman',
#  'Elephant',
#  'Ebrima',
#  'HYGraphic-Medium',
#  'Onyx',
#  'Calibri',
#  'Segoe UI Variable',
#  'Bauhaus 93',
#  'Britannic Bold',
#  'Garamond',
#  'HCR Batang ExtB',
#  'Palatino Linotype',
#  'HYPost-Medium',
#  'Lucida Sans Unicode',
#  'SimSun',
#  'Microsoft Tai Le',
#  'Rockwell',
#  'Segoe UI',
#  'STKaiti',
#  'Times New Roman',
#  'Segoe Print',
#  'Tw Cen MT',
#  'Palatino Linotype',
#  'Segoe UI',
#  'Yet R',
#  'Cambria',
#  'Lucida Fax',
#  'Broadway',
#  'Bodoni MT',
#  'Microsoft JhengHei',
#  'Broadway',
#  'Parchment',
#  'Bookman Old Style',
#  'FZShuTi',
#  'Lucida Sans',
#  'Cambria',
#  'Gill Sans MT',
#  'HYGungSo-Bold',
#  'HYPost-Medium',
#  'Candara',
#  'Javanese Text',
#  'Franklin Gothic Demi',
#  'Viner Hand ITC',
#  'High Tower Text',
#  'Comic Sans MS',
#  'Lucida Bright',
#  'Mongolian Baiti',
#  'MV Boli',
#  'Curlz MT',
#  'Sans Serif Collection',
#  'Noto Sans Korean',
#  'HYPost-Light',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Yu Gothic',
#  'Gabriola',
#  'Arial',
#  'Nirmala UI',
#  'Calibri',
#  'Yu Gothic',
#  'Goudy Old Style',
#  'Gadugi',
#  'Consolas',
#  'Wide Latin',
#  'Magneto',
#  'Vivaldi',
#  'Snap ITC',
#  'Ink Free',
#  'Colonna MT',
#  'Berlin Sans FB',
#  'Bookman Old Style',
#  'Courier New',
#  'Poor Richard',
#  'Mongolian Baiti',
#  'Consolas',
#  'Lucida Fax',
#  'Calibri',
#  'Segoe UI',
#  'Century Gothic',
#  'Segoe Fluent Icons',
#  'Segoe MDL2 Assets',
#  'Microsoft Yi Baiti',
#  'Lucida Sans Typewriter',
#  'Segoe UI Variable',
#  'Microsoft Sans Serif',
#  'HCR Batang ExtB',
#  'Corbel',
#  'STKaiti',
#  'Dubai',
#  'Lucida Sans Typewriter',
#  'Vladimir Script',
#  'Arial Rounded MT Bold',
#  'Segoe UI',
#  'MS Reference Sans Serif',
#  'Magic R',
#  'HYShortSamul-Medium',
#  'Segoe UI',
#  'HYSinMyeongJo-Medium',
#  'Haettenschweiler',
#  'Mistral',
#  'Dubai',
#  'STFangsong',
#  'MT Extra',
#  'Book Antiqua',
#  'Lucida Sans Typewriter',
#  'Consolas',
#  'Century Schoolbook',
#  'Franklin Gothic Heavy',
#  'Georgia',
#  'Bell MT',
#  'HYGungSo-Bold',
#  'Tw Cen MT',
#  'Hancom Gothic',
#  'Lucida Sans Typewriter',
#  'STZhongsong',
#  'YouYuan',
#  'Book Antiqua',
#  'Niagara Solid',
#  'Rockwell',
#  'MingLiU-ExtB',
#  'Rockwell Condensed',
#  'HYShortSamul-Medium',
#  'Calisto MT',
#  'Bell MT',
#  'Dubai',
#  'Leelawadee UI',
#  'Bell MT',
#  'Microsoft JhengHei',
#  'Arial',
#  'Sylfaen',
#  'New Gulim',
#  'Castellar',
#  'Noto Sans Korean',
#  'Monotype Corsiva',
#  'Trebuchet MS',
#  'Microsoft Tai Le',
#  'STXihei',
#  'Century',
#  'Copperplate Gothic Light',
#  'Malgun Gothic',
#  'Segoe UI',
#  'Arial',
#  'Colonna MT',
#  'Franklin Gothic Medium Cond',
#  'SimSun-ExtB',
#  'Constantia',
#  'Microsoft YaHei',
#  'Georgia',
#  'Franklin Gothic Heavy',
#  'Pristina',
#  'HyhwpEQ',
#  'Malgun Gothic',
#  'Verdana',
#  'Bodoni MT',
#  'Bodoni MT',
#  'HyhwpEQ',
#  'Garamond',
#  'Courier New',
#  'Bookman Old Style',
#  'Goudy Stout',
#  'Gill Sans Ultra Bold Condensed',
#  'Pristina',
#  'Han Santteut Dotum',
#  'Franklin Gothic Medium',
#  'Segoe UI',
#  'Engravers MT',
#  'Franklin Gothic Demi Cond',
#  'Gill Sans MT',
#  'Berlin Sans FB',
#  'Segoe Script',
#  'Rockwell Condensed',
#  'Consolas',
#  'HCR Dotum',
#  'Myanmar Text',
#  'Sitka',
#  'Lucida Console',
#  'Rockwell',
#  'Verdana',
#  'Leelawadee UI',
#  'Century Schoolbook',
#  'HCR Batang Ext',
#  'STCaiyun',
#  'LiSu',
#  'Nirmala UI',
#  'Malgun Gothic',
#  'Perpetua Titling MT',
#  'Calisto MT',
#  'YouYuan',
#  'HCR Dotum Ext',
#  'Century Gothic',
#  'Old English Text MT',
#  'Arial',
#  'Tw Cen MT Condensed Extra Bold',
#  'Lucida Sans',
#  'Impact',
#  'Haan Wing2',
#  'Calibri',
#  'Headline R',
#  'Perpetua Titling MT',
#  'Algerian',
#  'Microsoft YaHei',
#  'Microsoft PhagsPa',
#  'Goudy Old Style',
#  'SimSun-ExtB',
#  'Garamond',
#  'Tw Cen MT Condensed Extra Bold',
#  'NanumGothic',
#  'Viner Hand ITC',
#  'Lucida Fax',
#  'Microsoft Sans Serif',
#  'STCaiyun',
#  'Candara',
#  'Consolas',
#  'Sans Serif Collection',
#  'Palatino Linotype',
#  'Bradley Hand ITC',
#  'Bodoni MT',
#  'FZYaoTi',
#  'HoloLens MDL2 Assets',
#  'Goudy Old Style',
#  'Comic Sans MS',
#  'Lucida Bright',
#  'HCR Batang ExtB',
#  'Wide Latin',
#  'MoeumT R',
#  'HYGothic-Extra',
#  'Palatino Linotype',
#  'Tw Cen MT',
#  'Calisto MT',
#  'Nirmala UI',
#  'Franklin Gothic Medium Cond',
#  'Century Schoolbook',
#  'Franklin Gothic Demi',
#  'Bodoni MT',
#  'Lucida Bright',
#  'Haettenschweiler',
#  'Felix Titling',
#  'Ebrima',
#  'Snap ITC',
#  'Lucida Sans Typewriter',
#  'Perpetua',
#  'Pyunji R',
#  'Lucida Sans',
#  'Ravie',
#  'Bookman Old Style',
#  'KBFG Text',
#  'MS Reference Specialty',
#  'Bradley Hand ITC',
#  'Niagara Engraved',
#  'Dubai',
#  'Bodoni MT',
#  'Eras Light ITC',
#  'Lucida Sans',
#  'Microsoft Himalaya',
#  'Lucida Sans Typewriter',
#  'Eras Bold ITC',
#  'Eras Medium ITC',
#  'Gulim',
#  'Nirmala UI',
#  'MS Reference Sans Serif',
#  'Tw Cen MT',
#  'Rockwell',
#  'Segoe Script',
#  'Palace Script MT',
#  'Century Gothic',
#  'HYMyeongJo-Extra',
#  'Cooper Black',
#  'Bodoni MT',
#  'OCR A Extended',
#  'Dubai',
#  'Old English Text MT',
#  'Lucida Sans',
#  'Georgia',
#  'Californian FB',
#  'Footlight MT Light',
#  'Bodoni MT',
#  'Microsoft PhagsPa',
#  'Century Gothic',
#  'Courier New',
#  'Harlow Solid Italic',
#  'STLiti',
#  'Century Gothic',
#  'Yu Gothic',
#  'Lucida Bright',
#  'Times New Roman',
#  'Corbel',
#  'NanumGothic',
#  'Century Schoolbook',
#  'Verdana',
#  'Informal Roman',
#  'HYHeadLine-Medium',
#  'Script MT Bold',
#  'Imprint MT Shadow',
#  'MS Reference Specialty',
#  'NanumGothic',
#  'Corbel',
#  'Chiller',
#  'Kristen ITC',
#  'Verdana',
#  'Rage Italic',
#  'Segoe UI',
#  'Bodoni MT',
#  'Matura MT Script Capitals',
#  'HYHeadLine-Medium',
#  'Times New Roman',
#  'Agency FB',
#  'Constantia',
#  'Lucida Sans Typewriter',
#  'Comic Sans MS',
#  'Palatino Linotype',
#  'Verdana',
#  'Sitka',
#  'Stencil',
#  'Nina',
#  'Webdings',
#  'Tw Cen MT',
#  'Hancom Gothic',
#  'Lucida Calligraphy',
#  'Ami R',
#  'Microsoft YaHei',
#  'Tw Cen MT Condensed',
#  'Nina',
#  'Franklin Gothic Medium',
#  'Gigi',
#  'Bodoni MT',
#  'Malgun Gothic',
#  'Showcard Gothic',
#  'Baskerville Old Face',
#  'Calisto MT',
#  'Lucida Sans',
#  'Arial',
#  'Bodoni MT',
#  'Juice ITC',
#  'Century Gothic',
#  'Rockwell Condensed',
#  'Courier New',
#  'Calibri',
#  'Cambria',
#  'Marlett',
#  'Harlow Solid Italic',
#  'Forte',
#  'Playbill',
#  'Century Schoolbook',
#  'Noto Sans Korean',
#  'Matura MT Script Capitals',
#  'Mistral',
#  'Segoe Fluent Icons',
#  'Franklin Gothic Demi Cond',
#  'Freestyle Script',
#  'Segoe UI',
#  'Elephant',
#  'Microsoft YaHei',
#  'Arial',
#  'Segoe UI',
#  'Century Schoolbook',
#  'Papyrus',
#  'Comic Sans MS',
#  'HCR Batang',
#  'Cambria',
#  'Verdana',
#  'Tw Cen MT',
#  'Bodoni MT',
#  'STZhongsong',
#  'HCR Dotum',
#  'Corbel',
#  'Curlz MT',
#  'Palatino Linotype',
#  'Goudy Old Style',
#  'Segoe Print',
#  'Segoe Script',
#  'Lucida Handwriting',
#  'Franklin Gothic Medium',
#  'Nirmala UI',
#  'FZYaoTi',
#  'Informal Roman',
#  'Californian FB',
#  'Berlin Sans FB Demi',
#  'MS Outlook',
#  'Segoe UI Symbol',
#  'Perpetua',
#  'Rage Italic',
#  'Garamond',
#  'Agency FB',
#  'Agency FB',
#  'Tw Cen MT Condensed',
#  'Haan Wing2',
#  'Corbel',
#  'Modern No. 20',
#  'Tempus Sans ITC',
#  'Gill Sans MT',
#  'Segoe UI',
#  'Britannic Bold',
#  'Constantia',
#  'Courier New',
#  'Kunstler Script',
#  'Perpetua Titling MT',
#  'Wingdings',
#  'Book Antiqua',
#  'Segoe UI Historic',
#  'Trebuchet MS',
#  'Segoe UI',
#  'Microsoft Tai Le',
#  'Castellar',
#  'Rockwell',
#  'Candara',
#  'Segoe Print',
#  'Bookman Old Style',
#  'STXingkai',
#  'Gadugi',
#  'Niagara Solid',
#  'Calibri',
#  'Perpetua',
#  'Georgia',
#  'Chiller',
#  'Segoe UI',
#  'Consolas',
#  'Segoe Script',
#  'Candara',
#  'Rockwell Extra Bold',
#  'Batang',
#  'Bernard MT Condensed',
#  'Leelawadee UI',
#  'Bookshelf Symbol 7',
#  'Cooper Black',
#  'Century Schoolbook',
#  'STLiti',
#  'Cambria',
#  'Dubai',
#  'Microsoft JhengHei',
#  'STXihei',
#  'Lucida Handwriting',
#  'Felix Titling',
#  'Gigi',
#  'Microsoft JhengHei',
#  'Forte',
#  'Stencil',
#  'Garamond',
#  'Times New Roman',
#  'Courier New',
#  'Bell MT',
#  'Sitka',
#  'Imprint MT Shadow',
#  'Book Antiqua',
#  'Constantia',
#  'Franklin Gothic Book',
#  'Edwardian Script ITC',
#  'Arial',
#  'Baskerville Old Face',
#  'Corbel',
#  'Lucida Bright',
#  'Century Gothic',
#  'LiSu',
#  'Gill Sans Ultra Bold',
#  'Rockwell Extra Bold',
#  'Bodoni MT',
#  'Gill Sans MT Ext Condensed Bold',
#  'Blackadder ITC',
#  'Gloucester MT Extra Condensed',
#  'Calibri',
#  'Copperplate Gothic Light',
#  'Arial',
#  'Calibri',
#  'Segoe UI',
#  'Franklin Gothic Demi',
#  'Segoe UI',
#  'Franklin Gothic Heavy',
#  'Trebuchet MS',
#  'Brush Script MT',
#  'Trebuchet MS',
#  'Arial',
#  'Georgia',
#  'Tw Cen MT Condensed',
#  'Bahnschrift',
#  'FZShuTi',
#  'Corbel',
#  'MT Extra',
#  'Javanese Text',
#  'Microsoft PhagsPa',
#  'Han Santteut Dotum',
#  'Symbol',
#  'Palatino Linotype',
#  'Gabriola',
#  'Leelawadee UI',
#  'High Tower Text',
#  'STFangsong',
#  'Headline R',
#  'HYGothic-Medium',
#  'Juice ITC',
#  'Impact',
#  'Monotype Corsiva',
#  'French Script MT',
#  'Times New Roman',
#  'Webdings',
#  'Onyx',
#  'Lucida Fax',
#  'Ink Free',
#  'Yu Gothic',
#  'HYPMokGak-Bold',
#  'Lucida Console',
#  'Constantia',
#  'HCR Dotum Ext',
#  'Papyrus',
#  'Bodoni MT',
#  'Trebuchet MS',
#  'Microsoft Himalaya',
#  'Bookman Old Style',
#  'Californian FB',
#  'Noto Sans Korean',
#  'Wingdings 2',
#  'Constantia',
#  'Perpetua',
#  'Ravie',
#  'Arial',
#  'Harrington',
#  'Gill Sans MT',
#  'Arial',
#  'Sylfaen',
#  'Microsoft New Tai Lue',
#  'Arial',
#  'Perpetua',
#  'Eras Demi ITC',
#  'Georgia',
#  'Times New Roman',
#  'Nina',
#  'Cambria',
#  'Bernard MT Condensed',
#  'Yu Gothic',
#  'HYGothic-Medium',
#  'Segoe MDL2 Assets',
#  'Candara',
#  'Segoe UI',
#  'Gulim',
#  'Niagara Engraved',
#  'Bodoni MT',
#  'Perpetua Titling MT',
#  'HCR Batang ExtB',
#  'Kristen ITC',
#  'Corbel',
#  'Comic Sans MS',
#  'Berlin Sans FB',
#  'STHupo',
#  'Courier New',
#  'Tempus Sans ITC',
#  'Freestyle Script',
#  'Calisto MT',
#  'Myanmar Text',
#  'Gill Sans MT',
#  'Bodoni MT']

# %%
plt.plot(x, y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
